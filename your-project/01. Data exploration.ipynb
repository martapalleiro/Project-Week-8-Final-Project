# %% [markdown]
# ## Importing libraries

# %%
import os
import sys

from PIL import Image
import numpy as np
from numpy.random import seed
seed(42)
import pandas as pd 
import random
import glob
import re
from scipy import interp  
from itertools import cycle
import shutil

import matplotlib.pyplot as plt
import seaborn as sns
import ipywidgets as widgets
# %matplotlib inline
import cv2

# %% [markdown]
# ## Data exploration

# %%
#CSV with 50 most influential artists and some information about them
artists = pd.read_csv("Data/artists.csv", index_col=0)
artists
# Out:
#                          name        years  \
# id
# 0           Amedeo Modigliani  1884 - 1920
# 1          Vasiliy Kandinskiy  1866 - 1944
# 2                Diego Rivera  1886 - 1957
# 3                Claude Monet  1840 - 1926
# 4               Rene Magritte  1898 - 1967
# 5               Salvador Dali  1904 - 1989
# 6               Edouard Manet  1832 - 1883
# 7               Andrei Rublev  1360 - 1430
# 8            Vincent van Gogh  1853 – 1890
# 9                Gustav Klimt  1862 - 1918
# 10           Hieronymus Bosch  1450 - 1516
# 11           Kazimir Malevich  1879 - 1935
# 12             Mikhail Vrubel  1856 - 1910
# 13              Pablo Picasso  1881 - 1973
# 14          Peter Paul Rubens  1577 - 1640
# 15      Pierre-Auguste Renoir  1841 - 1919
# 16             Francisco Goya  1746 - 1828
# 17                Frida Kahlo  1907 - 1954
# 18                   El Greco  1541 - 1614
# 19             Albrecht Dürer  1471 - 1528
# 20              Alfred Sisley  1839 - 1899
# ...

# %%
#Which artists have more paintings? 
artists.loc[artists['paintings'] > 300]
# Out:
#                      name        years                         genre  \
# id
# 8        Vincent van Gogh  1853 – 1890            Post-Impressionism
# 13          Pablo Picasso  1881 - 1973                        Cubism
# 15  Pierre-Auguste Renoir  1841 - 1919                 Impressionism
# 19         Albrecht Dürer  1471 - 1528          Northern Renaissance
# 30            Edgar Degas  1834 - 1917                 Impressionism
# 46           Paul Gauguin  1848 – 1903  Symbolism,Post-Impressionism
#
#    nationality                                                bio  \
# id
# 8        Dutch  Vincent Willem van Gogh (Dutch: [ˈvɪnsɛnt ˈʋɪl...
# 13     Spanish  Pablo Ruiz Picasso (; Spanish: [ˈpaβlo piˈkaso...
# 15      French  Pierre-Auguste Renoir, commonly known as Augus...
# 19      German  Albrecht Dürer (; German: [ˈʔalbʁɛçt ˈdyːʁɐ]; ...
# 30      French  Edgar Degas (US:  or UK: ; born Hilaire-Germai...
# 46      French  Eugène Henri Paul Gauguin (UK: , US: ; French:...
#
# ...

# %%
#Opening one image
img_raw = cv2.imread('Data/Artists_4/Paul_Gauguin_123.jpg', 1)

# %%
type(img_raw)
np.ndarray
img_raw.shape
# Out:
# (1024, 837, 3)

# %%
plt.imshow(img_raw)
